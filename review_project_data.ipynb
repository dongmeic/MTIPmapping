# %%
import pandas as pd

# %%
file = r'T:\MPO\TIP\TIP FY24-27\Maps\Data\24-27 MTIP list (draft) 20221121.xlsx'

# %%
data_cl = pd.read_excel(file, skiprows=3, nrows=28)

# %%
data_cl.head(3)
# Out:
#                       Project Name  MTIP ID #  \
# 0                              NaN        NaN
# 1  Central Lane MPO planning SFY25   191003.0
# 2                              NaN        NaN
#
#                                  Project Description Work Type Perf. Meas.  \
# 0                                                NaN       NaN         NaN
# 1  Central Lane MPO planning funds for Federal fi...        PL          --
# 2                                                NaN       NaN         NaN
#
#   RTP Project Number / Ref.  In AQ CATS?  In\nAQMA?  \
# 0                       NaN          NaN        NaN
# 1                        --          NaN        NaN
# 2                       NaN          NaN        NaN
#
#                                   Air Quality Status  STIP Key  ...  \
# 0                                                NaN       NaN  ...
# 1  EXEMPT / Other-Planning and Technical Studies ...   21864.0  ...
# ...
